# %%
# Disparate ratio
# Data
selected_x = 80
applicants_x = 200
selected_y = 40
applicants_y = 100

# Selection rates
rate_x = selected_x / applicants_x
rate_y = selected_y / applicants_y

# Disparate impact ratio (usually minority/majority)
disparate_impact = rate_y / rate_x

rate_x, rate_y, disparate_impact

print('Disparate Ratio: ', disparate_impact)
print('Since DPR > 0.8 there is no disparate impact')
# Out:
# Disparate Ratio:  1.0
# Since DPR > 0.8 there is no disparate impact
